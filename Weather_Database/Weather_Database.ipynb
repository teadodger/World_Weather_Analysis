# %%
# 1. Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0c1ba86cb8f77380ad856565e1a6aae2

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 802

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
   # Group cities in sets of 50 for logging purposes
   if (i % 50 == 0 and i >= 50):
       set_count += 1
       record_count = 1
       time.sleep(60)
   # Create endpoint URL with each city
   city_url = url + "&q=" + city.replace(" ","+")
   # Log the url, record, and set numbers
   print(f"Processing Record {record_count} of Set {set_count} | {city}")
   # Add 1 to the record count
   record_count += 1
   # Run an API request for each of the cities
   try:
       city_weather = requests.get(city_url).json()
       # Parse out the max temp, humidity, and cloudiness
       city_lat = city_weather["coord"]["lat"]
       city_lng = city_weather["coord"]["lon"]
       city_max_temp = city_weather["main"]["temp_max"]
       city_humidity = city_weather["main"]["humidity"]
       city_clouds = city_weather["clouds"]["all"]
       city_wind = city_weather["wind"]["speed"]
       city_country = city_weather["sys"]["country"]
       city_weather_description = city_weather["weather"][0]["description"]
           # Append the City information into city_data list
          # Convert the date to ISO standard.
       city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Date": city_date,
                         "Max Temp": city_max_temp,
                         "Current Description": city_weather_description,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country})
   # If an error is experienced, skip the city
   except:
       print("City not found. Skipping...")
       pass
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | morgan city
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | kitui
# Processing Record 6 of Set 1 | platanos
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | chapais
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | bengkulu
# Processing Record 13 of Set 1 | armidale
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | olinda
# Processing Record 17 of Set 1 | lerwick
# Processing Record 18 of Set 1 | kysyl-syr
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | jinchang
# Processing Record 22 of Set 1 | severobaykalsk
# Processing Record 23 of Set 1 | warri
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | chunoyar
# Processing Record 28 of Set 1 | yar-sale
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | arkhara
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | oranjestad
# Processing Record 35 of Set 1 | kavieng
# Processing Record 36 of Set 1 | esqueda
# Processing Record 37 of Set 1 | safaga
# Processing Record 38 of Set 1 | nishihara
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | aljezur
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | westport
# Processing Record 45 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 1 | severnoye
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | klaksvik
# Processing Record 49 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | port macquarie
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | ambon
# Processing Record 4 of Set 2 | agadez
# Processing Record 5 of Set 2 | rio gallegos
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | borogontsy
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | zainsk
# Processing Record 10 of Set 2 | port hueneme
# Processing Record 11 of Set 2 | tura
# Processing Record 12 of Set 2 | ust-koksa
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | escalerillas
# Processing Record 15 of Set 2 | namatanai
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | maniitsoq
# Processing Record 18 of Set 2 | sisimiut
# Processing Record 19 of Set 2 | beringovskiy
# Processing Record 20 of Set 2 | hammerfest
# Processing Record 21 of Set 2 | itacarambi
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | varadero
# Processing Record 25 of Set 2 | asyut
# Processing Record 26 of Set 2 | nizhniy kuranakh
# Processing Record 27 of Set 2 | vila
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | lasem
# Processing Record 31 of Set 2 | kenora
# Processing Record 32 of Set 2 | sivas
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | misratah
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | monrovia
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | zabaykalsk
# Processing Record 41 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 2 | kruisfontein
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | harper
# Processing Record 45 of Set 2 | muhos
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | muros
# Processing Record 48 of Set 2 | aguimes
# Processing Record 49 of Set 2 | sambhar
# Processing Record 50 of Set 2 | sovetskaya gavan
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | marsh harbour
# Processing Record 3 of Set 3 | tucurui
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | osoyoos
# Processing Record 7 of Set 3 | bambanglipuro
# Processing Record 8 of Set 3 | stromness
# Processing Record 9 of Set 3 | saint-francois
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | pisco
# Processing Record 12 of Set 3 | hobart
# Processing Record 13 of Set 3 | namibe
# Processing Record 14 of Set 3 | dergachi
# Processing Record 15 of Set 3 | balkhash
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | rocha
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | bababe
# City not found. Skipping...
# Processing Record 20 of Set 3 | pandua
# Processing Record 21 of Set 3 | formosa
# Processing Record 22 of Set 3 | kalmunai
# Processing Record 23 of Set 3 | mount gambier
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | quesnel
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | gao
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | naze
# Processing Record 32 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 3 | mareeba
# Processing Record 34 of Set 3 | nakamura
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | rey bouba
# Processing Record 37 of Set 3 | gamba
# Processing Record 38 of Set 3 | normandin
# Processing Record 39 of Set 3 | haines junction
# Processing Record 40 of Set 3 | labuhan
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | fukue
# Processing Record 43 of Set 3 | mayumba
# Processing Record 44 of Set 3 | nemuro
# Processing Record 45 of Set 3 | khanpur
# Processing Record 46 of Set 3 | atuona
# Processing Record 47 of Set 3 | general roca
# Processing Record 48 of Set 3 | boyolangu
# Processing Record 49 of Set 3 | airai
# Processing Record 50 of Set 3 | motygino
# Processing Record 1 of Set 4 | lebu
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | lata
# Processing Record 5 of Set 4 | itarema
# Processing Record 6 of Set 4 | bathsheba
# Processing Record 7 of Set 4 | bilma
# Processing Record 8 of Set 4 | majene
# Processing Record 9 of Set 4 | port elizabeth
# Processing Record 10 of Set 4 | samfya
# Processing Record 11 of Set 4 | salamiyah
# Processing Record 12 of Set 4 | vilyuysk
# Processing Record 13 of Set 4 | buchanan
# Processing Record 14 of Set 4 | lompoc
# Processing Record 15 of Set 4 | chirgaon
# Processing Record 16 of Set 4 | dauphin
# Processing Record 17 of Set 4 | ahmadpur
# Processing Record 18 of Set 4 | bandarbeyla
# Processing Record 19 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 4 | bethel
# Processing Record 22 of Set 4 | hermanus
# Processing Record 23 of Set 4 | iskateley
# Processing Record 24 of Set 4 | tuatapere
# Processing Record 25 of Set 4 | kirakira
# Processing Record 26 of Set 4 | miranda
# Processing Record 27 of Set 4 | taoudenni
# Processing Record 28 of Set 4 | tabuk
# Processing Record 29 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 4 | innisfail
# Processing Record 31 of Set 4 | jennings
# Processing Record 32 of Set 4 | zhuanghe
# Processing Record 33 of Set 4 | miyako
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | hofn
# Processing Record 36 of Set 4 | vaini
# Processing Record 37 of Set 4 | inongo
# Processing Record 38 of Set 4 | maarianhamina
# Processing Record 39 of Set 4 | seymchan
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | alice springs
# Processing Record 42 of Set 4 | tubuala
# Processing Record 43 of Set 4 | old shinyanga
# Processing Record 44 of Set 4 | cotonou
# Processing Record 45 of Set 4 | yantal
# Processing Record 46 of Set 4 | rabo de peixe
# Processing Record 47 of Set 4 | torrevieja
# Processing Record 48 of Set 4 | tutoia
# Processing Record 49 of Set 4 | avarua
# Processing Record 50 of Set 4 | fairbanks
# Processing Record 1 of Set 5 | puerto escondido
# Processing Record 2 of Set 5 | eregli
# Processing Record 3 of Set 5 | lircay
# Processing Record 4 of Set 5 | grand gaube
# Processing Record 5 of Set 5 | majdanpek
# Processing Record 6 of Set 5 | matagami
# Processing Record 7 of Set 5 | bogo
# Processing Record 8 of Set 5 | ponta delgada
# Processing Record 9 of Set 5 | korla
# Processing Record 10 of Set 5 | half moon bay
# Processing Record 11 of Set 5 | fallon
# Processing Record 12 of Set 5 | marsabit
# Processing Record 13 of Set 5 | bossier city
# Processing Record 14 of Set 5 | brae
# Processing Record 15 of Set 5 | lingao
# Processing Record 16 of Set 5 | pringsewu
# Processing Record 17 of Set 5 | saint george
# Processing Record 18 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 5 | mwinilunga
# Processing Record 21 of Set 5 | saskylakh
# Processing Record 22 of Set 5 | college
# Processing Record 23 of Set 5 | tuysarkan
# City not found. Skipping...
# Processing Record 24 of Set 5 | shepsi
# Processing Record 25 of Set 5 | yuanping
# Processing Record 26 of Set 5 | nantucket
# Processing Record 27 of Set 5 | altay
# Processing Record 28 of Set 5 | bubaque
# Processing Record 29 of Set 5 | mackay
# Processing Record 30 of Set 5 | port blair
# Processing Record 31 of Set 5 | champerico
# Processing Record 32 of Set 5 | copperas cove
# Processing Record 33 of Set 5 | dongsheng
# Processing Record 34 of Set 5 | angoche
# Processing Record 35 of Set 5 | chunhuhub
# Processing Record 36 of Set 5 | ledyard
# Processing Record 37 of Set 5 | barguzin
# Processing Record 38 of Set 5 | ilulissat
# Processing Record 39 of Set 5 | palana
# Processing Record 40 of Set 5 | celestun
# Processing Record 41 of Set 5 | rawson
# Processing Record 42 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 5 | tecoanapa
# Processing Record 45 of Set 5 | necochea
# Processing Record 46 of Set 5 | gerash
# Processing Record 47 of Set 5 | bireun
# Processing Record 48 of Set 5 | umm kaddadah
# Processing Record 49 of Set 5 | kloulklubed
# Processing Record 50 of Set 5 | sao fidelis
# Processing Record 1 of Set 6 | vung tau
# Processing Record 2 of Set 6 | xichang
# Processing Record 3 of Set 6 | ahipara
# Processing Record 4 of Set 6 | nome
# Processing Record 5 of Set 6 | yurimaguas
# Processing Record 6 of Set 6 | manjacaze
# Processing Record 7 of Set 6 | preobrazheniye
# Processing Record 8 of Set 6 | san patricio
# Processing Record 9 of Set 6 | cidreira
# Processing Record 10 of Set 6 | shumyachi
# Processing Record 11 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 6 | banganapalle
# Processing Record 13 of Set 6 | saldanha
# Processing Record 14 of Set 6 | cocoa beach
# Processing Record 15 of Set 6 | coos bay
# Processing Record 16 of Set 6 | benghazi
# Processing Record 17 of Set 6 | bajil
# Processing Record 18 of Set 6 | quzhou
# Processing Record 19 of Set 6 | peruibe
# Processing Record 20 of Set 6 | provideniya
# Processing Record 21 of Set 6 | dunedin
# Processing Record 22 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 6 | constitucion
# Processing Record 24 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 6 | talnakh
# Processing Record 26 of Set 6 | valreas
# Processing Record 27 of Set 6 | yatou
# Processing Record 28 of Set 6 | teknaf
# Processing Record 29 of Set 6 | muli
# Processing Record 30 of Set 6 | buluang
# Processing Record 31 of Set 6 | piacabucu
# Processing Record 32 of Set 6 | basco
# Processing Record 33 of Set 6 | goma
# Processing Record 34 of Set 6 | vagay
# Processing Record 35 of Set 6 | bento goncalves
# Processing Record 36 of Set 6 | awbari
# Processing Record 37 of Set 6 | split
# Processing Record 38 of Set 6 | kodiak
# Processing Record 39 of Set 6 | lukovetskiy
# Processing Record 40 of Set 6 | killybegs
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | naruto
# Processing Record 43 of Set 6 | narasannapeta
# Processing Record 44 of Set 6 | bodden town
# Processing Record 45 of Set 6 | sioux lookout
# Processing Record 46 of Set 6 | lluta
# Processing Record 47 of Set 6 | matamoros
# Processing Record 48 of Set 6 | bom jesus
# Processing Record 49 of Set 6 | vestmannaeyjar
# Processing Record 50 of Set 6 | tiznit
# Processing Record 1 of Set 7 | torbay
# Processing Record 2 of Set 7 | sitka
# Processing Record 3 of Set 7 | saint-louis
# Processing Record 4 of Set 7 | faanui
# Processing Record 5 of Set 7 | torbat-e jam
# Processing Record 6 of Set 7 | komsomolskiy
# Processing Record 7 of Set 7 | pevek
# Processing Record 8 of Set 7 | skibbereen
# Processing Record 9 of Set 7 | pangody
# Processing Record 10 of Set 7 | sorong
# Processing Record 11 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 7 | santa maria
# Processing Record 13 of Set 7 | turukhansk
# Processing Record 14 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 7 | novyy urgal
# Processing Record 16 of Set 7 | muravlenko
# Processing Record 17 of Set 7 | zhigansk
# Processing Record 18 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 7 | alta floresta
# Processing Record 20 of Set 7 | along
# Processing Record 21 of Set 7 | flin flon
# Processing Record 22 of Set 7 | amreli
# Processing Record 23 of Set 7 | vardo
# Processing Record 24 of Set 7 | leningradskiy
# Processing Record 25 of Set 7 | eureka
# Processing Record 26 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 7 | acarau
# Processing Record 28 of Set 7 | iqaluit
# Processing Record 29 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 7 | chernyshevskiy
# Processing Record 31 of Set 7 | betioky
# Processing Record 32 of Set 7 | flinders
# Processing Record 33 of Set 7 | nabire
# Processing Record 34 of Set 7 | san juan
# Processing Record 35 of Set 7 | norman wells
# Processing Record 36 of Set 7 | yuxia
# Processing Record 37 of Set 7 | noyabrsk
# Processing Record 38 of Set 7 | touros
# Processing Record 39 of Set 7 | belaya gora
# Processing Record 40 of Set 7 | albenga
# Processing Record 41 of Set 7 | sao filipe
# Processing Record 42 of Set 7 | namtsy
# Processing Record 43 of Set 7 | tombouctou
# Processing Record 44 of Set 7 | hambantota
# Processing Record 45 of Set 7 | presidente franco
# Processing Record 46 of Set 7 | banda aceh
# Processing Record 47 of Set 7 | surt
# Processing Record 48 of Set 7 | zorgo
# Processing Record 49 of Set 7 | jati
# Processing Record 50 of Set 7 | cukai
# Processing Record 1 of Set 8 | kamina
# Processing Record 2 of Set 8 | pangnirtung
# Processing Record 3 of Set 8 | cutro
# Processing Record 4 of Set 8 | araouane
# Processing Record 5 of Set 8 | isangel
# Processing Record 6 of Set 8 | tilichiki
# Processing Record 7 of Set 8 | praia da vitoria
# Processing Record 8 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 8 | shunyi
# Processing Record 10 of Set 8 | rio grande
# Processing Record 11 of Set 8 | hovd
# Processing Record 12 of Set 8 | hervey bay
# Processing Record 13 of Set 8 | bac lieu
# Processing Record 14 of Set 8 | tondano
# Processing Record 15 of Set 8 | zhuhai
# Processing Record 16 of Set 8 | prince rupert
# Processing Record 17 of Set 8 | moron
# Processing Record 18 of Set 8 | katsuura
# Processing Record 19 of Set 8 | comodoro rivadavia
# Processing Record 20 of Set 8 | trofors
# Processing Record 21 of Set 8 | ibra
# Processing Record 22 of Set 8 | fort smith
# Processing Record 23 of Set 8 | vanimo
# Processing Record 24 of Set 8 | lavrentiya
# Processing Record 25 of Set 8 | acapulco
# Processing Record 26 of Set 8 | sambava
# Processing Record 27 of Set 8 | vega de alatorre
# Processing Record 28 of Set 8 | baykit
# Processing Record 29 of Set 8 | marzuq
# Processing Record 30 of Set 8 | souillac
# Processing Record 31 of Set 8 | that phanom
# Processing Record 32 of Set 8 | kamariotissa
# Processing Record 33 of Set 8 | altamira
# Processing Record 34 of Set 8 | yankton
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | berlevag
# Processing Record 37 of Set 8 | lorengau
# Processing Record 38 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 8 | palasa
# Processing Record 40 of Set 8 | chumikan
# Processing Record 41 of Set 8 | zwettl
# Processing Record 42 of Set 8 | bhadasar
# Processing Record 43 of Set 8 | thilogne
# City not found. Skipping...
# Processing Record 44 of Set 8 | marystown
# Processing Record 45 of Set 8 | aklavik
# Processing Record 46 of Set 8 | sao joao da barra
# Processing Record 47 of Set 8 | coihaique
# Processing Record 48 of Set 8 | roald
# Processing Record 49 of Set 8 | beira
# Processing Record 50 of Set 8 | longyearbyen
# Processing Record 1 of Set 9 | yagodnoye
# Processing Record 2 of Set 9 | aloleng
# Processing Record 3 of Set 9 | krabi
# Processing Record 4 of Set 9 | srandakan
# Processing Record 5 of Set 9 | narva-joesuu
# Processing Record 6 of Set 9 | miyang
# Processing Record 7 of Set 9 | narsaq
# Processing Record 8 of Set 9 | hay river
# Processing Record 9 of Set 9 | yarmouth
# Processing Record 10 of Set 9 | richards bay
# Processing Record 11 of Set 9 | notse
# Processing Record 12 of Set 9 | ambilobe
# Processing Record 13 of Set 9 | belmonte
# Processing Record 14 of Set 9 | pokhara
# Processing Record 15 of Set 9 | warrington
# Processing Record 16 of Set 9 | okrika
# Processing Record 17 of Set 9 | alenquer
# Processing Record 18 of Set 9 | kesova gora
# Processing Record 19 of Set 9 | kaitangata
# Processing Record 20 of Set 9 | dingle
# Processing Record 21 of Set 9 | hun
# Processing Record 22 of Set 9 | qaqortoq
# Processing Record 23 of Set 9 | kotelnich
# Processing Record 24 of Set 9 | anekal
# Processing Record 25 of Set 9 | clyde river
# Processing Record 26 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 9 | rosarito
# Processing Record 28 of Set 9 | coquimbo
# Processing Record 29 of Set 9 | vuktyl
# Processing Record 30 of Set 9 | alyangula
# Processing Record 31 of Set 9 | norfolk
# Processing Record 32 of Set 9 | guerrero negro
# Processing Record 33 of Set 9 | monte patria
# Processing Record 34 of Set 9 | mayo
# Processing Record 35 of Set 9 | gubbi
# Processing Record 36 of Set 9 | yumen
# Processing Record 37 of Set 9 | jomalig
# City not found. Skipping...
# Processing Record 38 of Set 9 | kinablangan
# Processing Record 39 of Set 9 | caravelas
# Processing Record 40 of Set 9 | a
# City not found. Skipping...
# Processing Record 41 of Set 9 | skagen
# Processing Record 42 of Set 9 | barcelos
# Processing Record 43 of Set 9 | charters towers
# Processing Record 44 of Set 9 | nampa
# Processing Record 45 of Set 9 | adrar
# Processing Record 46 of Set 9 | andros town
# Processing Record 47 of Set 9 | the valley
# Processing Record 48 of Set 9 | hurricane
# Processing Record 49 of Set 9 | san cristobal
# Processing Record 50 of Set 9 | upington
# Processing Record 1 of Set 10 | poum
# Processing Record 2 of Set 10 | gazli
# Processing Record 3 of Set 10 | coahuayana
# Processing Record 4 of Set 10 | roma
# Processing Record 5 of Set 10 | karasjok
# Processing Record 6 of Set 10 | zhangye
# Processing Record 7 of Set 10 | shumskiy
# Processing Record 8 of Set 10 | homberg
# Processing Record 9 of Set 10 | jiangyou
# Processing Record 10 of Set 10 | coari
# Processing Record 11 of Set 10 | skelleftea
# Processing Record 12 of Set 10 | hansot
# Processing Record 13 of Set 10 | havelock
# Processing Record 14 of Set 10 | poronaysk
# Processing Record 15 of Set 10 | saint-pierre
# Processing Record 16 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 17 of Set 10 | kahului
# Processing Record 18 of Set 10 | bay city
# Processing Record 19 of Set 10 | perth
# Processing Record 20 of Set 10 | pitimbu
# Processing Record 21 of Set 10 | tambo
# Processing Record 22 of Set 10 | faya
# Processing Record 23 of Set 10 | lucapa
# Processing Record 24 of Set 10 | turtas
# Processing Record 25 of Set 10 | baraboo
# Processing Record 26 of Set 10 | bageshwar
# Processing Record 27 of Set 10 | merauke
# Processing Record 28 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 29 of Set 10 | vallenar
# Processing Record 30 of Set 10 | gouyave
# Processing Record 31 of Set 10 | shizuishan
# Processing Record 32 of Set 10 | kifri
# Processing Record 33 of Set 10 | xai-xai
# Processing Record 34 of Set 10 | boljarovo
# City not found. Skipping...
# Processing Record 35 of Set 10 | lakefield
# Processing Record 36 of Set 10 | lianran
# Processing Record 37 of Set 10 | pimentel
# Processing Record 38 of Set 10 | merrill
# Processing Record 39 of Set 10 | vao
# Processing Record 40 of Set 10 | gazanjyk
# Processing Record 41 of Set 10 | gummidipundi
# Processing Record 42 of Set 10 | matay
# Processing Record 43 of Set 10 | waipawa
# Processing Record 44 of Set 10 | san carlos de bariloche
# Processing Record 45 of Set 10 | tahta
# Processing Record 46 of Set 10 | menongue
# Processing Record 47 of Set 10 | langres
# Processing Record 48 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 10 | atar
# Processing Record 50 of Set 10 | oistins
# Processing Record 1 of Set 11 | boa vista
# Processing Record 2 of Set 11 | katobu
# Processing Record 3 of Set 11 | simpang
# Processing Record 4 of Set 11 | shchuchye
# City not found. Skipping...
# Processing Record 5 of Set 11 | esperance
# Processing Record 6 of Set 11 | mackenzie
# Processing Record 7 of Set 11 | abha
# Processing Record 8 of Set 11 | daru
# Processing Record 9 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 10 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 11 | amapa
# Processing Record 12 of Set 11 | morlaix
# Processing Record 13 of Set 11 | senno
# Processing Record 14 of Set 11 | dicabisagan
# Processing Record 15 of Set 11 | anadyr
# Processing Record 16 of Set 11 | salinas
# Processing Record 17 of Set 11 | torres
# Processing Record 18 of Set 11 | klyuchi
# Processing Record 19 of Set 11 | yulara
# Processing Record 20 of Set 11 | bonoua
# Processing Record 21 of Set 11 | makakilo city
# Processing Record 22 of Set 11 | del rio
# Processing Record 23 of Set 11 | zimovniki
# Processing Record 24 of Set 11 | mugur-aksy
# Processing Record 25 of Set 11 | binga
# Processing Record 26 of Set 11 | male
# Processing Record 27 of Set 11 | young
# Processing Record 28 of Set 11 | paamiut
# Processing Record 29 of Set 11 | poltavka
# Processing Record 30 of Set 11 | smithers
# Processing Record 31 of Set 11 | westfield
# Processing Record 32 of Set 11 | aksarka
# Processing Record 33 of Set 11 | kandrian
# Processing Record 34 of Set 11 | wanaka
# Processing Record 35 of Set 11 | pacific grove
# Processing Record 36 of Set 11 | jardim
# Processing Record 37 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 38 of Set 11 | port augusta
# Processing Record 39 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 11 | byron bay
# Processing Record 41 of Set 11 | doha
# Processing Record 42 of Set 11 | mecca
# Processing Record 43 of Set 11 | san pedro de tutule
# Processing Record 44 of Set 11 | lima
# Processing Record 45 of Set 11 | alta gracia
# Processing Record 46 of Set 11 | kon tum
# Processing Record 47 of Set 11 | ballina
# Processing Record 48 of Set 11 | kemijarvi
# Processing Record 49 of Set 11 | praia
# Processing Record 50 of Set 11 | ancud
# Processing Record 1 of Set 12 | paramonga
# Processing Record 2 of Set 12 | horsham
# Processing Record 3 of Set 12 | bolshaya dzhalga
# Processing Record 4 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 12 | vanavara
# Processing Record 6 of Set 12 | lexington
# Processing Record 7 of Set 12 | fonte boa
# Processing Record 8 of Set 12 | bairiki
# Processing Record 9 of Set 12 | nuevo progreso
# Processing Record 10 of Set 12 | filingue
# Processing Record 11 of Set 12 | astoria
# Processing Record 12 of Set 12 | danville
# Processing Record 13 of Set 12 | jalu
# Processing Record 14 of Set 12 | bansi
# Processing Record 15 of Set 12 | belyy yar
# Processing Record 16 of Set 12 | cayenne
# Processing Record 17 of Set 12 | leshukonskoye
# Processing Record 18 of Set 12 | sao jose da coroa grande
# Processing Record 19 of Set 12 | avera
# Processing Record 20 of Set 12 | pareora
# Processing Record 21 of Set 12 | burnie
# Processing Record 22 of Set 12 | sayyan
# Processing Record 23 of Set 12 | nizhniy chir
# Processing Record 24 of Set 12 | sale
# Processing Record 25 of Set 12 | waingapu
# Processing Record 26 of Set 12 | chuy
# Processing Record 27 of Set 12 | atasu
# Processing Record 28 of Set 12 | alakurtti
# Processing Record 29 of Set 12 | lunglei
# Processing Record 30 of Set 12 | shawnee
# Processing Record 31 of Set 12 | sokolo
# Processing Record 32 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 12 | nova olimpia
# Processing Record 34 of Set 12 | den helder
# Processing Record 35 of Set 12 | kyren
# Processing Record 36 of Set 12 | havre
# Processing Record 37 of Set 12 | russell
# Processing Record 38 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 39 of Set 12 | srednekolymsk
# Processing Record 40 of Set 12 | ixtapa
# Processing Record 41 of Set 12 | harindanga
# Processing Record 42 of Set 12 | loukhi
# Processing Record 43 of Set 12 | batemans bay
# Processing Record 44 of Set 12 | el balyana
# City not found. Skipping...
# Processing Record 45 of Set 12 | kangaatsiaq
# Processing Record 46 of Set 12 | adzope
# Processing Record 47 of Set 12 | suntar
# Processing Record 48 of Set 12 | broken hill
# Processing Record 49 of Set 12 | cabras
# Processing Record 50 of Set 12 | tambura
# Processing Record 1 of Set 13 | atagay
# Processing Record 2 of Set 13 | el sauzal
# Processing Record 3 of Set 13 | emet
# Processing Record 4 of Set 13 | salinopolis
# Processing Record 5 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 6 of Set 13 | takoradi
# Processing Record 7 of Set 13 | sarangani
# Processing Record 8 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 9 of Set 13 | bangkalan
# Processing Record 10 of Set 13 | ipixuna
# Processing Record 11 of Set 13 | maningrida
# Processing Record 12 of Set 13 | kyshtovka
# Processing Record 13 of Set 13 | ayan
# Processing Record 14 of Set 13 | koplik
# Processing Record 15 of Set 13 | conceicao da barra
# Processing Record 16 of Set 13 | axim
# Processing Record 17 of Set 13 | naples
# Processing Record 18 of Set 13 | dwarka
# Processing Record 19 of Set 13 | bell ville
# Processing Record 20 of Set 13 | orissaare
# Processing Record 21 of Set 13 | manokwari
# Processing Record 22 of Set 13 | aswan
# Processing Record 23 of Set 13 | easton
# Processing Record 24 of Set 13 | rumboci
# Processing Record 25 of Set 13 | voh
# Processing Record 26 of Set 13 | luba
# Processing Record 27 of Set 13 | belen
# Processing Record 28 of Set 13 | nambucca heads
# Processing Record 29 of Set 13 | coihueco
# Processing Record 30 of Set 13 | ilinskiy
# Processing Record 31 of Set 13 | la suiza
# Processing Record 32 of Set 13 | paraiso
# Processing Record 33 of Set 13 | kudahuvadhoo
# Processing Record 34 of Set 13 | sarkand
# Processing Record 35 of Set 13 | taltal
# Processing Record 36 of Set 13 | millau
# Processing Record 37 of Set 13 | moussoro
# Processing Record 38 of Set 13 | rajapur
# Processing Record 39 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 13 | akhalgori
# Processing Record 41 of Set 13 | walvis bay
# Processing Record 42 of Set 13 | mahajanga
# Processing Record 43 of Set 13 | salisbury
# Processing Record 44 of Set 13 | manoel urbano
# Processing Record 45 of Set 13 | babynino
# Processing Record 46 of Set 13 | alofi
# Processing Record 47 of Set 13 | nador
# Processing Record 48 of Set 13 | botwood
# Processing Record 49 of Set 13 | kaliganj
# Processing Record 50 of Set 13 | tigil
# Processing Record 1 of Set 14 | superior
# Processing Record 2 of Set 14 | ewa beach
# Processing Record 3 of Set 14 | cabedelo
# Processing Record 4 of Set 14 | baracoa
# Processing Record 5 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 14 | mayor pablo lagerenza
# Processing Record 7 of Set 14 | nazare
# Processing Record 8 of Set 14 | mpika
# Processing Record 9 of Set 14 | samut songkhram
# Processing Record 10 of Set 14 | ternate
# Processing Record 11 of Set 14 | boralday
# Processing Record 12 of Set 14 | zhuji
# Processing Record 13 of Set 14 | vengerovo
# Processing Record 14 of Set 14 | yamethin
# Processing Record 15 of Set 14 | corn island
# Processing Record 16 of Set 14 | ouallam
# Processing Record 17 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 18 of Set 14 | serebryanyy bor
# Processing Record 19 of Set 14 | ormara
# Processing Record 20 of Set 14 | sosnovo-ozerskoye
# Processing Record 21 of Set 14 | vieques
# Processing Record 22 of Set 14 | haputale
# Processing Record 23 of Set 14 | san vicente
# Processing Record 24 of Set 14 | pilar
# Processing Record 25 of Set 14 | krasnoselkup
# Processing Record 26 of Set 14 | mizan teferi
# Processing Record 27 of Set 14 | palestine
# Processing Record 28 of Set 14 | sovetskiy
# Processing Record 29 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 30 of Set 14 | izyum
# Processing Record 31 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 14 | thanjavur
# Processing Record 33 of Set 14 | sistranda
# Processing Record 34 of Set 14 | sobolevo
# Processing Record 35 of Set 14 | yei
# Processing Record 36 of Set 14 | mogadishu
# Processing Record 37 of Set 14 | tanete
# Processing Record 38 of Set 14 | ugoofaaru
# Processing Record 39 of Set 14 | bosanski brod
# Processing Record 40 of Set 14 | grojec
# Processing Record 41 of Set 14 | bosaso
# Processing Record 42 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 14 | ferkessedougou
# Processing Record 44 of Set 14 | palmer
# Processing Record 45 of Set 14 | waddan
# Processing Record 46 of Set 14 | vila franca do campo
# Processing Record 47 of Set 14 | banjar
# Processing Record 48 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 14 | kathmandu
# Processing Record 50 of Set 14 | abiy adi
# City not found. Skipping...
# Processing Record 1 of Set 15 | balykshi
# Processing Record 2 of Set 15 | gat
# Processing Record 3 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 15 | kalabo
# Processing Record 5 of Set 15 | murray bridge
# Processing Record 6 of Set 15 | gomel
# Processing Record 7 of Set 15 | urumqi
# Processing Record 8 of Set 15 | nanortalik
# Processing Record 9 of Set 15 | antsohihy
# Processing Record 10 of Set 15 | bilibino
# Processing Record 11 of Set 15 | puerto carreno
# Processing Record 12 of Set 15 | kasongo-lunda
# Processing Record 13 of Set 15 | price
# Processing Record 14 of Set 15 | burgeo
# Processing Record 15 of Set 15 | kangaba
# Processing Record 16 of Set 15 | balkanabat
# Processing Record 17 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 15 | tateyama
# Processing Record 19 of Set 15 | mahanoro
# Processing Record 20 of Set 15 | el dorado
# Processing Record 21 of Set 15 | krasnyy chikoy
# Processing Record 22 of Set 15 | derzhavinsk
# Processing Record 23 of Set 15 | port keats
# Processing Record 24 of Set 15 | penzance
# Processing Record 25 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 26 of Set 15 | hobyo
# Processing Record 27 of Set 15 | karaton
# Processing Record 28 of Set 15 | arandis
# Processing Record 29 of Set 15 | bethanien
# Processing Record 30 of Set 15 | carutapera
# Processing Record 31 of Set 15 | sunbury
# Processing Record 32 of Set 15 | constantine
# Processing Record 33 of Set 15 | plouzane
# Processing Record 34 of Set 15 | outlook
# Processing Record 35 of Set 15 | portoviejo
# Processing Record 36 of Set 15 | johnstown
# Processing Record 37 of Set 15 | mandalgovi
# Processing Record 38 of Set 15 | jacareacanga
# Processing Record 39 of Set 15 | puerto narino
# Processing Record 40 of Set 15 | kavaratti
# Processing Record 41 of Set 15 | nyurba
# Processing Record 42 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 15 | broome
# Processing Record 44 of Set 15 | wabag
# Processing Record 45 of Set 15 | caudebec-les-elbeuf
# Processing Record 46 of Set 15 | olafsvik
# Processing Record 47 of Set 15 | bac giang
# Processing Record 48 of Set 15 | kiruna
# Processing Record 49 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 50 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 1 of Set 16 | meulaboh
# Processing Record 2 of Set 16 | tessalit
# Processing Record 3 of Set 16 | verkhniy uslon
# Processing Record 4 of Set 16 | cabinda
# Processing Record 5 of Set 16 | marsala
# Processing Record 6 of Set 16 | bonthe
# Processing Record 7 of Set 16 | jibuti
# Processing Record 8 of Set 16 | nuuk
# Processing Record 9 of Set 16 | salalah
# Processing Record 10 of Set 16 | asadabad
# Processing Record 11 of Set 16 | dudinka
# Processing Record 12 of Set 16 | ketchikan
# Processing Record 13 of Set 16 | bitung
# Processing Record 14 of Set 16 | shizunai
# Processing Record 15 of Set 16 | otavi
# Processing Record 16 of Set 16 | natal
# Processing Record 17 of Set 16 | pampa
# Processing Record 18 of Set 16 | meadow lake
# Processing Record 19 of Set 16 | saint-augustin
# Processing Record 20 of Set 16 | shache
# Processing Record 21 of Set 16 | boulder city
# Processing Record 22 of Set 16 | baghdad
# Processing Record 23 of Set 16 | sao miguel do araguaia
# Processing Record 24 of Set 16 | pochutla
# Processing Record 25 of Set 16 | ust-nera
# Processing Record 26 of Set 16 | makubetsu
# Processing Record 27 of Set 16 | talcahuano
# Processing Record 28 of Set 16 | ryde
# Processing Record 29 of Set 16 | victor harbor
# Processing Record 30 of Set 16 | pekan
# Processing Record 31 of Set 16 | kuminskiy
# Processing Record 32 of Set 16 | gamboula
# Processing Record 33 of Set 16 | urdzhar
# City not found. Skipping...
# Processing Record 34 of Set 16 | fortuna
# Processing Record 35 of Set 16 | parambu
# Processing Record 36 of Set 16 | roatan
# Processing Record 37 of Set 16 | mwene-ditu
# Processing Record 38 of Set 16 | teguise
# Processing Record 39 of Set 16 | abnub
# Processing Record 40 of Set 16 | cojasca
# Processing Record 41 of Set 16 | sur
# Processing Record 42 of Set 16 | korampallam
# Processing Record 43 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 16 | lundazi
# Processing Record 45 of Set 16 | ampanihy
# Processing Record 46 of Set 16 | tynda
# Processing Record 47 of Set 16 | high level
# Processing Record 48 of Set 16 | likasi
# Processing Record 49 of Set 16 | emba
# Processing Record 50 of Set 16 | margate
# Processing Record 1 of Set 17 | nur
# Processing Record 2 of Set 17 | te anau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng                 Date  Max Temp  \
# 0        Mataura -46.1927  168.8643  2021-11-27 05:41:39     55.00
# 1         Barrow  71.2906 -156.7887  2021-11-27 05:40:02    -16.58
# 2    Morgan City  29.6994  -91.2068  2021-11-27 05:41:39     48.20
# 3         Albany  42.6001  -73.9662  2021-11-27 05:41:39     30.61
# 4          Kitui  -1.3670   38.0106  2021-11-27 05:41:40     69.49
# ..           ...      ...       ...                  ...       ...
# 733       Likasi -10.9814   26.7333  2021-11-27 06:00:38     63.32
# 734         Emba  48.8264   58.1442  2021-11-27 06:00:38     21.65
# 735      Margate  51.3813    1.3862  2021-11-27 06:00:39     37.11
# 736          Nur  52.6683   22.3221  2021-11-27 06:01:39     35.02
# 737      Te Anau -45.4167  167.7167  2021-11-27 06:01:39     55.24
#
#     Current Description  Humidity  Cloudiness  Wind Speed Country
# 0       overcast clouds        53         100        6.82      NZ
# 1             clear sky        69           1        5.75      US
# 2             clear sky        87           1        0.00      US
# 3            light snow        75          95       16.84      US
# 4            light rain        82          93        4.68      KE
# ..                  ...       ...         ...         ...     ...
# 733     overcast clouds        95          96        4.90      CD
# 734     overcast clouds        76          95        6.04      KZ
# 735     overcast clouds        92         100       18.54      GB
# 736          light snow        99         100        2.26      PL
# 737     overcast clouds        62          99        1.41      NZ
#
# [738 rows x 10 columns]

# %%
city_data_columns_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

city_data_columns_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mataura      NZ -46.1927  168.8643     55.00        53         100
# 1         Barrow      US  71.2906 -156.7887    -16.58        69           1
# 2    Morgan City      US  29.6994  -91.2068     48.20        87           1
# 3         Albany      US  42.6001  -73.9662     30.61        75          95
# 4          Kitui      KE  -1.3670   38.0106     69.49        82          93
# ..           ...     ...      ...       ...       ...       ...         ...
# 733       Likasi      CD -10.9814   26.7333     63.32        95          96
# 734         Emba      KZ  48.8264   58.1442     21.65        76          95
# 735      Margate      GB  51.3813    1.3862     37.11        92         100
# 736          Nur      PL  52.6683   22.3221     35.02        99         100
# 737      Te Anau      NZ -45.4167  167.7167     55.24        62          99
#
#      Wind Speed Current Description
# 0          6.82     overcast clouds
# 1          5.75           clear sky
# 2          0.00           clear sky
# 3         16.84          light snow
# 4          4.68          light rain
# ..          ...                 ...
# 733        4.90     overcast clouds
# 734        6.04     overcast clouds
# 735       18.54     overcast clouds
# 736        2.26          light snow
# 737        1.41     overcast clouds
#
# [738 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_columns_df.to_csv(output_data_file, index_label="City_ID")

city_data_columns_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mataura      NZ -46.1927  168.8643     55.00        53         100
# 1         Barrow      US  71.2906 -156.7887    -16.58        69           1
# 2    Morgan City      US  29.6994  -91.2068     48.20        87           1
# 3         Albany      US  42.6001  -73.9662     30.61        75          95
# 4          Kitui      KE  -1.3670   38.0106     69.49        82          93
# ..           ...     ...      ...       ...       ...       ...         ...
# 733       Likasi      CD -10.9814   26.7333     63.32        95          96
# 734         Emba      KZ  48.8264   58.1442     21.65        76          95
# 735      Margate      GB  51.3813    1.3862     37.11        92         100
# 736          Nur      PL  52.6683   22.3221     35.02        99         100
# 737      Te Anau      NZ -45.4167  167.7167     55.24        62          99
#
#      Wind Speed Current Description
# 0          6.82     overcast clouds
# 1          5.75           clear sky
# 2          0.00           clear sky
# 3         16.84          light snow
# 4          4.68          light rain
# ..          ...                 ...
# 733        4.90     overcast clouds
# 734        6.04     overcast clouds
# 735       18.54     overcast clouds
# 736        2.26          light snow
# 737        1.41     overcast clouds
#
# [738 rows x 9 columns]
