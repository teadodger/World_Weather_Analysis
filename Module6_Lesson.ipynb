# %%
# 1. Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0c1ba86cb8f77380ad856565e1a6aae2

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 597

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
   # Group cities in sets of 50 for logging purposes
   if (i % 50 == 0 and i >= 50):
       set_count += 1
       record_count = 1
       time.sleep(60)
   # Create endpoint URL with each city
   city_url = url + "&q=" + city.replace(" ","+")
   # Log the url, record, and set numbers
   print(f"Processing Record {record_count} of Set {set_count} | {city}")
   # Add 1 to the record count
   record_count += 1
   # Run an API request for each of the cities
   try:
       city_weather = requests.get(city_url).json()
       # Parse out the max temp, humidity, and cloudiness
       city_lat = city_weather["coord"]["lat"]
       city_lng = city_weather["coord"]["lon"]
       city_max_temp = city_weather["main"]["temp_max"]
       city_humidity = city_weather["main"]["humidity"]
       city_clouds = city_weather["clouds"]["all"]
       city_wind = city_weather["wind"]["speed"]
       city_country = city_weather["sys"]["country"]
       city_weather_description = city_weather["weather"][0]["description"]
           # Append the City information into city_data list
          # Convert the date to ISO standard.
       city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Date": city_date,
                         "Max Temp": city_max_temp,
                         "Current Description": city_weather_description,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country})
   # If an error is experienced, skip the city
   except:
       print("City not found. Skipping...")
       pass
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | husavik
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | bal-os
# Processing Record 12 of Set 1 | sayyan
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | norsup
# Processing Record 15 of Set 1 | manchester
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | yanam
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | mount gambier
# Processing Record 21 of Set 1 | orsha
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | fortuna
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | new ulm
# Processing Record 26 of Set 1 | halifax
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | aktash
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | saint-michel-des-saints
# Processing Record 31 of Set 1 | sur
# Processing Record 32 of Set 1 | lagoa
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | puerto pinasco
# City not found. Skipping...
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | guanica
# Processing Record 40 of Set 1 | darhan
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | mehnagar
# Processing Record 44 of Set 1 | clyde river
# Processing Record 45 of Set 1 | sterling
# Processing Record 46 of Set 1 | gornopravdinsk
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 1 | aykhal
# Processing Record 50 of Set 1 | kirakira
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | cherskiy
# Processing Record 4 of Set 2 | codrington
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | statesboro
# Processing Record 7 of Set 2 | cockburn town
# Processing Record 8 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 2 | kruisfontein
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | vanavara
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | sao joao da barra
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | san patricio
# Processing Record 17 of Set 2 | aswan
# Processing Record 18 of Set 2 | bubaque
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | atambua
# Processing Record 21 of Set 2 | chibombo
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | narsaq
# Processing Record 27 of Set 2 | bengkulu
# Processing Record 28 of Set 2 | tiznit
# Processing Record 29 of Set 2 | rajaldesar
# Processing Record 30 of Set 2 | waingapu
# Processing Record 31 of Set 2 | axim
# Processing Record 32 of Set 2 | takaka
# Processing Record 33 of Set 2 | hoquiam
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | leningradskiy
# Processing Record 36 of Set 2 | hofn
# Processing Record 37 of Set 2 | sakakah
# Processing Record 38 of Set 2 | yerbogachen
# Processing Record 39 of Set 2 | fort nelson
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | machali
# Processing Record 44 of Set 2 | okhotsk
# Processing Record 45 of Set 2 | saint-pierre
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | wake forest
# Processing Record 48 of Set 2 | san diego de los banos
# Processing Record 49 of Set 2 | warman
# Processing Record 50 of Set 2 | oranjemund
# Processing Record 1 of Set 3 | road town
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | tazmalt
# Processing Record 4 of Set 3 | ahipara
# Processing Record 5 of Set 3 | katobu
# Processing Record 6 of Set 3 | hailar
# Processing Record 7 of Set 3 | nabire
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | mocuba
# Processing Record 10 of Set 3 | raudeberg
# Processing Record 11 of Set 3 | tuatapere
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | namibe
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | hede
# Processing Record 17 of Set 3 | takoradi
# Processing Record 18 of Set 3 | puerto leguizamo
# Processing Record 19 of Set 3 | champerico
# Processing Record 20 of Set 3 | pringsewu
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | thomaston
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | rio claro
# Processing Record 32 of Set 3 | easton
# Processing Record 33 of Set 3 | omboue
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 3 | vilhena
# Processing Record 37 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 3 | bellary
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | buraydah
# Processing Record 41 of Set 3 | arcachon
# Processing Record 42 of Set 3 | port keats
# Processing Record 43 of Set 3 | santa rosa
# Processing Record 44 of Set 3 | college
# Processing Record 45 of Set 3 | amahai
# Processing Record 46 of Set 3 | olafsvik
# Processing Record 47 of Set 3 | ruidoso
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | oriximina
# Processing Record 50 of Set 3 | san carlos del zulia
# Processing Record 1 of Set 4 | port lincoln
# Processing Record 2 of Set 4 | umm lajj
# Processing Record 3 of Set 4 | biak
# Processing Record 4 of Set 4 | yaguajay
# Processing Record 5 of Set 4 | isla mujeres
# Processing Record 6 of Set 4 | anadyr
# Processing Record 7 of Set 4 | dina
# Processing Record 8 of Set 4 | changli
# Processing Record 9 of Set 4 | gat
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | flinders
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | gushikawa
# Processing Record 15 of Set 4 | karpathos
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | salalah
# Processing Record 18 of Set 4 | busselton
# Processing Record 19 of Set 4 | talnakh
# Processing Record 20 of Set 4 | rawson
# Processing Record 21 of Set 4 | dudinka
# Processing Record 22 of Set 4 | nosy varika
# Processing Record 23 of Set 4 | hobyo
# Processing Record 24 of Set 4 | kulhudhuffushi
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 4 | lensk
# Processing Record 28 of Set 4 | eyl
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | hackettstown
# Processing Record 31 of Set 4 | moose factory
# Processing Record 32 of Set 4 | mahebourg
# Processing Record 33 of Set 4 | puerto escondido
# Processing Record 34 of Set 4 | kidal
# Processing Record 35 of Set 4 | beloomut
# Processing Record 36 of Set 4 | arroyo
# Processing Record 37 of Set 4 | vao
# Processing Record 38 of Set 4 | chapais
# Processing Record 39 of Set 4 | maluso
# Processing Record 40 of Set 4 | sangar
# Processing Record 41 of Set 4 | mao
# Processing Record 42 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 43 of Set 4 | dawei
# Processing Record 44 of Set 4 | sitka
# Processing Record 45 of Set 4 | ugoofaaru
# Processing Record 46 of Set 4 | hithadhoo
# Processing Record 47 of Set 4 | arraial do cabo
# Processing Record 48 of Set 4 | lebu
# Processing Record 49 of Set 4 | hoima
# Processing Record 50 of Set 4 | aleksandrovka
# Processing Record 1 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 5 | chicama
# Processing Record 3 of Set 5 | kishi
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | lavrentiya
# Processing Record 6 of Set 5 | kandrian
# Processing Record 7 of Set 5 | elektrenai
# Processing Record 8 of Set 5 | thohoyandou
# Processing Record 9 of Set 5 | areosa
# Processing Record 10 of Set 5 | serdobsk
# Processing Record 11 of Set 5 | torbay
# Processing Record 12 of Set 5 | hambantota
# Processing Record 13 of Set 5 | heihe
# Processing Record 14 of Set 5 | abbeville
# Processing Record 15 of Set 5 | ushtobe
# Processing Record 16 of Set 5 | hare bay
# Processing Record 17 of Set 5 | birao
# Processing Record 18 of Set 5 | port macquarie
# Processing Record 19 of Set 5 | dinard
# Processing Record 20 of Set 5 | viedma
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | berdigestyakh
# Processing Record 23 of Set 5 | te anau
# Processing Record 24 of Set 5 | carahue
# Processing Record 25 of Set 5 | marawi
# Processing Record 26 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | ubinskoye
# Processing Record 29 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | fairbanks
# Processing Record 32 of Set 5 | yuzhou
# Processing Record 33 of Set 5 | north bend
# Processing Record 34 of Set 5 | belmonte
# Processing Record 35 of Set 5 | lieksa
# Processing Record 36 of Set 5 | nishihara
# Processing Record 37 of Set 5 | kyren
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | bodden town
# Processing Record 40 of Set 5 | faya
# Processing Record 41 of Set 5 | sovetskiy
# Processing Record 42 of Set 5 | goderich
# Processing Record 43 of Set 5 | sheksna
# Processing Record 44 of Set 5 | nago
# Processing Record 45 of Set 5 | mecca
# Processing Record 46 of Set 5 | souillac
# Processing Record 47 of Set 5 | pendleton
# Processing Record 48 of Set 5 | balkanabat
# Processing Record 49 of Set 5 | lata
# Processing Record 50 of Set 5 | tateyama
# Processing Record 1 of Set 6 | ingham
# Processing Record 2 of Set 6 | vila
# Processing Record 3 of Set 6 | pran buri
# Processing Record 4 of Set 6 | anyang
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | vila franca do campo
# Processing Record 8 of Set 6 | mrakovo
# Processing Record 9 of Set 6 | orebro
# Processing Record 10 of Set 6 | roanoke rapids
# Processing Record 11 of Set 6 | daru
# Processing Record 12 of Set 6 | kieta
# Processing Record 13 of Set 6 | san mateo ixtatan
# Processing Record 14 of Set 6 | lazaro cardenas
# Processing Record 15 of Set 6 | san quintin
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | dawson creek
# Processing Record 18 of Set 6 | korla
# Processing Record 19 of Set 6 | sambava
# Processing Record 20 of Set 6 | tsumeb
# Processing Record 21 of Set 6 | cayenne
# Processing Record 22 of Set 6 | maragogi
# Processing Record 23 of Set 6 | okha
# Processing Record 24 of Set 6 | tikhmenevo
# City not found. Skipping...
# Processing Record 25 of Set 6 | ancud
# Processing Record 26 of Set 6 | fukue
# Processing Record 27 of Set 6 | bahia honda
# Processing Record 28 of Set 6 | tiruvottiyur
# City not found. Skipping...
# Processing Record 29 of Set 6 | duz
# City not found. Skipping...
# Processing Record 30 of Set 6 | along
# Processing Record 31 of Set 6 | tecolutla
# Processing Record 32 of Set 6 | dayong
# Processing Record 33 of Set 6 | huaicheng
# Processing Record 34 of Set 6 | mehamn
# Processing Record 35 of Set 6 | aras
# Processing Record 36 of Set 6 | kem
# Processing Record 37 of Set 6 | komagane
# Processing Record 38 of Set 6 | vila velha
# Processing Record 39 of Set 6 | tilichiki
# Processing Record 40 of Set 6 | vostok
# Processing Record 41 of Set 6 | petropavlovka
# Processing Record 42 of Set 6 | lubao
# Processing Record 43 of Set 6 | aripuana
# Processing Record 44 of Set 6 | sioux lookout
# Processing Record 45 of Set 6 | srikakulam
# Processing Record 46 of Set 6 | vraca
# Processing Record 47 of Set 6 | zheleznodorozhnyy
# Processing Record 48 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 49 of Set 6 | pangnirtung
# Processing Record 50 of Set 6 | tsogni
# Processing Record 1 of Set 7 | sinazongwe
# Processing Record 2 of Set 7 | lorengau
# Processing Record 3 of Set 7 | senador guiomard
# Processing Record 4 of Set 7 | ardabil
# Processing Record 5 of Set 7 | esperance
# Processing Record 6 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 7 | santo tomas
# Processing Record 8 of Set 7 | boyany
# Processing Record 9 of Set 7 | peleduy
# Processing Record 10 of Set 7 | tavira
# Processing Record 11 of Set 7 | constitucion
# Processing Record 12 of Set 7 | saint-francois
# Processing Record 13 of Set 7 | kabare
# Processing Record 14 of Set 7 | nome
# Processing Record 15 of Set 7 | buala
# Processing Record 16 of Set 7 | port augusta
# Processing Record 17 of Set 7 | solnechnyy
# Processing Record 18 of Set 7 | paita
# Processing Record 19 of Set 7 | nemuro
# Processing Record 20 of Set 7 | nuuk
# Processing Record 21 of Set 7 | vestmannaeyjar
# Processing Record 22 of Set 7 | meulaboh
# Processing Record 23 of Set 7 | nikolsk
# Processing Record 24 of Set 7 | lamar
# Processing Record 25 of Set 7 | oktyabrskoye
# Processing Record 26 of Set 7 | harnosand
# Processing Record 27 of Set 7 | riverton
# Processing Record 28 of Set 7 | katsuura
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | bandarbeyla
# Processing Record 31 of Set 7 | talcahuano
# Processing Record 32 of Set 7 | tigil
# Processing Record 33 of Set 7 | san ignacio
# Processing Record 34 of Set 7 | ajdabiya
# Processing Record 35 of Set 7 | taoudenni
# Processing Record 36 of Set 7 | sabang
# Processing Record 37 of Set 7 | panama city
# Processing Record 38 of Set 7 | nata
# Processing Record 39 of Set 7 | ngunguru
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | steamboat springs
# Processing Record 42 of Set 7 | point pedro
# Processing Record 43 of Set 7 | tazovskiy
# Processing Record 44 of Set 7 | mileanca
# Processing Record 45 of Set 7 | kaitangata
# Processing Record 46 of Set 7 | pafos
# Processing Record 47 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 7 | raga
# Processing Record 49 of Set 7 | tacuarembo
# Processing Record 50 of Set 7 | mumbwa
# Processing Record 1 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 2 of Set 8 | minsk
# Processing Record 3 of Set 8 | aklavik
# Processing Record 4 of Set 8 | nyuksenitsa
# Processing Record 5 of Set 8 | bow island
# Processing Record 6 of Set 8 | prince rupert
# Processing Record 7 of Set 8 | portland
# Processing Record 8 of Set 8 | whitianga
# Processing Record 9 of Set 8 | farim
# Processing Record 10 of Set 8 | el rosario
# Processing Record 11 of Set 8 | platanos
# Processing Record 12 of Set 8 | gorodishche
# Processing Record 13 of Set 8 | atbasar
# Processing Record 14 of Set 8 | ranong
# Processing Record 15 of Set 8 | zeya
# Processing Record 16 of Set 8 | wolsztyn
# Processing Record 17 of Set 8 | mae chan
# Processing Record 18 of Set 8 | acari
# Processing Record 19 of Set 8 | teknaf
# Processing Record 20 of Set 8 | yulara
# Processing Record 21 of Set 8 | tessalit
# Processing Record 22 of Set 8 | itarema
# Processing Record 23 of Set 8 | sapa
# Processing Record 24 of Set 8 | novyy urengoy
# Processing Record 25 of Set 8 | adrar
# Processing Record 26 of Set 8 | bathsheba
# Processing Record 27 of Set 8 | kal
# Processing Record 28 of Set 8 | kismayo
# Processing Record 29 of Set 8 | lianzhou
# Processing Record 30 of Set 8 | tonshayevo
# Processing Record 31 of Set 8 | tommot
# Processing Record 32 of Set 8 | pemangkat
# Processing Record 33 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 34 of Set 8 | ixtapa
# Processing Record 35 of Set 8 | sivaki
# Processing Record 36 of Set 8 | lashio
# Processing Record 37 of Set 8 | petropavlivka
# Processing Record 38 of Set 8 | evensk
# Processing Record 39 of Set 8 | emerald
# Processing Record 40 of Set 8 | barcelos
# Processing Record 41 of Set 8 | bayonet point
# Processing Record 42 of Set 8 | hasaki
# Processing Record 43 of Set 8 | ghatanji
# Processing Record 44 of Set 8 | piracanjuba
# Processing Record 45 of Set 8 | de aar
# Processing Record 46 of Set 8 | ostrovnoy
# Processing Record 47 of Set 8 | arlit
# Processing Record 48 of Set 8 | addis zemen
# City not found. Skipping...
# Processing Record 49 of Set 8 | camana
# Processing Record 50 of Set 8 | daliang
# Processing Record 1 of Set 9 | inirida
# Processing Record 2 of Set 9 | santa fe
# Processing Record 3 of Set 9 | zurrieq
# Processing Record 4 of Set 9 | ho chi minh city
# Processing Record 5 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 9 | joshimath
# Processing Record 7 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 8 of Set 9 | dutse
# Processing Record 9 of Set 9 | kalmunai
# Processing Record 10 of Set 9 | padang
# Processing Record 11 of Set 9 | otane
# Processing Record 12 of Set 9 | amapa
# Processing Record 13 of Set 9 | kawalu
# Processing Record 14 of Set 9 | rock sound
# Processing Record 15 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 16 of Set 9 | tura
# Processing Record 17 of Set 9 | grindavik
# Processing Record 18 of Set 9 | noyabrsk
# Processing Record 19 of Set 9 | migori
# Processing Record 20 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 9 | thaba nchu
# Processing Record 22 of Set 9 | karratha
# Processing Record 23 of Set 9 | palmer
# Processing Record 24 of Set 9 | valparaiso
# Processing Record 25 of Set 9 | soto la marina
# Processing Record 26 of Set 9 | torbat-e jam
# Processing Record 27 of Set 9 | kigali
# Processing Record 28 of Set 9 | hualmay
# Processing Record 29 of Set 9 | bay city
# Processing Record 30 of Set 9 | isabela
# Processing Record 31 of Set 9 | antalaha
# Processing Record 32 of Set 9 | palauig
# Processing Record 33 of Set 9 | houston
# Processing Record 34 of Set 9 | almaznyy
# Processing Record 35 of Set 9 | alice springs
# Processing Record 36 of Set 9 | la ronge
# Processing Record 37 of Set 9 | villa carlos paz
# Processing Record 38 of Set 9 | san matias
# Processing Record 39 of Set 9 | mago
# Processing Record 40 of Set 9 | kota belud
# Processing Record 41 of Set 9 | ponta delgada
# Processing Record 42 of Set 9 | plettenberg bay
# Processing Record 43 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 44 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 9 | khatanga
# Processing Record 46 of Set 9 | acapulco
# Processing Record 47 of Set 9 | nanortalik
# Processing Record 48 of Set 9 | yuci
# Processing Record 49 of Set 9 | guerrero negro
# Processing Record 50 of Set 9 | rocha
# Processing Record 1 of Set 10 | inhambane
# Processing Record 2 of Set 10 | carauari
# Processing Record 3 of Set 10 | olyka
# Processing Record 4 of Set 10 | narrabri
# Processing Record 5 of Set 10 | maceio
# Processing Record 6 of Set 10 | urubicha
# Processing Record 7 of Set 10 | yusva
# City not found. Skipping...
# Processing Record 8 of Set 10 | tocopilla
# Processing Record 9 of Set 10 | koslan
# Processing Record 10 of Set 10 | avera
# Processing Record 11 of Set 10 | calbuco
# Processing Record 12 of Set 10 | puerto madryn
# Processing Record 13 of Set 10 | ulladulla
# Processing Record 14 of Set 10 | utinga
# Processing Record 15 of Set 10 | golden
# Processing Record 16 of Set 10 | tual
# Processing Record 17 of Set 10 | marzuq
# Processing Record 18 of Set 10 | sept-iles
# Processing Record 19 of Set 10 | lipari
# Processing Record 20 of Set 10 | escanaba
# Processing Record 21 of Set 10 | los chiles
# Processing Record 22 of Set 10 | saint-louis
# Processing Record 23 of Set 10 | yarada
# Processing Record 24 of Set 10 | bollnas
# Processing Record 25 of Set 10 | margate
# Processing Record 26 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 10 | hami
# Processing Record 28 of Set 10 | matamoros
# Processing Record 29 of Set 10 | meget
# Processing Record 30 of Set 10 | price
# Processing Record 31 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 32 of Set 10 | lewistown
# Processing Record 33 of Set 10 | kodinsk
# Processing Record 34 of Set 10 | koscierzyna
# Processing Record 35 of Set 10 | saint george
# Processing Record 36 of Set 10 | finnsnes
# Processing Record 37 of Set 10 | turukhansk
# Processing Record 38 of Set 10 | xunchang
# Processing Record 39 of Set 10 | kursumlija
# Processing Record 40 of Set 10 | gibara
# Processing Record 41 of Set 10 | mitsamiouli
# Processing Record 42 of Set 10 | tonj
# Processing Record 43 of Set 10 | xai-xai
# Processing Record 44 of Set 10 | culaba
# Processing Record 45 of Set 10 | sao joao da boa vista
# Processing Record 46 of Set 10 | biloela
# Processing Record 47 of Set 10 | yar-sale
# Processing Record 48 of Set 10 | praxedis guerrero
# Processing Record 49 of Set 10 | nelson bay
# Processing Record 50 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 1 of Set 11 | kichmengskiy gorodok
# Processing Record 2 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 11 | kahului
# Processing Record 4 of Set 11 | chernyshevskiy
# Processing Record 5 of Set 11 | yermekeyevo
# Processing Record 6 of Set 11 | riviere-au-renard
# Processing Record 7 of Set 11 | makat
# Processing Record 8 of Set 11 | santa barbara
# Processing Record 9 of Set 11 | los llanos de aridane
# Processing Record 10 of Set 11 | breytovo
# Processing Record 11 of Set 11 | sechura
# Processing Record 12 of Set 11 | reconquista
# Processing Record 13 of Set 11 | boden
# Processing Record 14 of Set 11 | qixingtai
# Processing Record 15 of Set 11 | amnat charoen
# Processing Record 16 of Set 11 | senneterre
# Processing Record 17 of Set 11 | bonfim
# Processing Record 18 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 11 | fremont
# Processing Record 20 of Set 11 | yablonovo
# Processing Record 21 of Set 11 | nhulunbuy
# Processing Record 22 of Set 11 | trat
# Processing Record 23 of Set 11 | jaranwala
# Processing Record 24 of Set 11 | saint anthony
# Processing Record 25 of Set 11 | pryazha
# Processing Record 26 of Set 11 | poum
# Processing Record 27 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 11 | ust-kuyga
# Processing Record 29 of Set 11 | mount isa
# Processing Record 30 of Set 11 | beringovskiy
# Processing Record 31 of Set 11 | higuey
# City not found. Skipping...
# Processing Record 32 of Set 11 | arys
# Processing Record 33 of Set 11 | beyneu
# Processing Record 34 of Set 11 | naze
# Processing Record 35 of Set 11 | sanford
# Processing Record 36 of Set 11 | lanxi
# Processing Record 37 of Set 11 | gdynia
# Processing Record 38 of Set 11 | nalut
# Processing Record 39 of Set 11 | santo antonio do ica
# Processing Record 40 of Set 11 | coahuayana
# Processing Record 41 of Set 11 | nahrin
# Processing Record 42 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 11 | jambi
# Processing Record 44 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 11 | camocim
# Processing Record 46 of Set 11 | teguise
# Processing Record 47 of Set 11 | winslow
# Processing Record 48 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 49 of Set 11 | noumea
# Processing Record 50 of Set 11 | peace river
# Processing Record 1 of Set 12 | bitburg
# Processing Record 2 of Set 12 | matagami
# Processing Record 3 of Set 12 | makakilo city
# Processing Record 4 of Set 12 | ankpa
# Processing Record 5 of Set 12 | fallon
# Processing Record 6 of Set 12 | iwaki
# Processing Record 7 of Set 12 | gizo
# Processing Record 8 of Set 12 | talaya
# Processing Record 9 of Set 12 | ambilobe
# Processing Record 10 of Set 12 | loukhi
# Processing Record 11 of Set 12 | maumere
# Processing Record 12 of Set 12 | hvide sande
# Processing Record 13 of Set 12 | bintulu
# Processing Record 14 of Set 12 | santiago del estero
# Processing Record 15 of Set 12 | ivanteyevka
# Processing Record 16 of Set 12 | qinnan
# Processing Record 17 of Set 12 | saltillo
# Processing Record 18 of Set 12 | ponnani
# Processing Record 19 of Set 12 | guiren
# Processing Record 20 of Set 12 | ongandjera
# Processing Record 21 of Set 12 | moree
# Processing Record 22 of Set 12 | san pedro
# Processing Record 23 of Set 12 | upata
# Processing Record 24 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 25 of Set 12 | kloulklubed
# Processing Record 26 of Set 12 | crowley
# Processing Record 27 of Set 12 | de-kastri
# Processing Record 28 of Set 12 | voh
# Processing Record 29 of Set 12 | zhangye
# Processing Record 30 of Set 12 | riyadh
# Processing Record 31 of Set 12 | kinna
# Processing Record 32 of Set 12 | kedougou
# Processing Record 33 of Set 12 | kumluca
# Processing Record 34 of Set 12 | cuamba
# Processing Record 35 of Set 12 | johi
# Processing Record 36 of Set 12 | kaili
# Processing Record 37 of Set 12 | comodoro rivadavia
# Processing Record 38 of Set 12 | syracuse
# Processing Record 39 of Set 12 | gangapur
# Processing Record 40 of Set 12 | bismil
# Processing Record 41 of Set 12 | beaverlodge
# Processing Record 42 of Set 12 | the valley
# Processing Record 43 of Set 12 | asau
# Processing Record 44 of Set 12 | cururupu
# Processing Record 45 of Set 12 | shimoda
# Processing Record 46 of Set 12 | quatre cocos
# Processing Record 47 of Set 12 | umba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 554

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City      Lat       Lng                 Date  Max Temp  \
# 0        Thompson  55.7435  -97.8558  2021-11-26 22:38:02     14.16
# 1           Pevek  69.7008  170.3133  2021-11-26 22:38:02    -26.99
# 2        Hermanus -34.4187   19.2345  2021-11-26 22:38:02     64.15
# 3           Bluff -46.6000  168.3333  2021-11-26 22:38:03     50.31
# 4         Ushuaia -54.8000  -68.3000  2021-11-26 22:35:37     49.66
# ..            ...      ...       ...                  ...       ...
# 549          Asau  46.4333   26.4000  2021-11-26 22:51:27     41.92
# 550      Cururupu  -1.8283  -44.8683  2021-11-26 22:51:28     76.12
# 551       Shimoda  34.6667  138.9500  2021-11-26 22:51:28     53.17
# 552  Quatre Cocos -20.2078   57.7625  2021-11-26 22:51:28     73.51
# 553          Umba  66.6871   34.3429  2021-11-26 22:51:29     13.91
#
#     Current Description  Humidity  Cloudiness  Wind Speed Country
# 0            light snow        92          90        3.44      CA
# 1      scattered clouds        99          34        5.77      RU
# 2            light rain        92         100        7.02      ZA
# 3       overcast clouds        59         100        5.50      NZ
# 4         broken clouds        46          75       21.85      AR
# ..                  ...       ...         ...         ...     ...
# 549     overcast clouds        93         100        5.97      RO
# 550       broken clouds        89          83        3.44      BR
# 551           clear sky        53           0       18.32      JP
# 552           clear sky        70           0        4.81      MU
# 553          few clouds        91          23        8.95      RU
#
# [554 rows x 10 columns]

# %%
city_data_df[["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]]
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0        Thompson      CA  2021-11-26 22:38:02  55.7435  -97.8558     14.16
# 1           Pevek      RU  2021-11-26 22:38:02  69.7008  170.3133    -26.99
# 2        Hermanus      ZA  2021-11-26 22:38:02 -34.4187   19.2345     64.15
# 3           Bluff      NZ  2021-11-26 22:38:03 -46.6000  168.3333     50.31
# 4         Ushuaia      AR  2021-11-26 22:35:37 -54.8000  -68.3000     49.66
# ..            ...     ...                  ...      ...       ...       ...
# 549          Asau      RO  2021-11-26 22:51:27  46.4333   26.4000     41.92
# 550      Cururupu      BR  2021-11-26 22:51:28  -1.8283  -44.8683     76.12
# 551       Shimoda      JP  2021-11-26 22:51:28  34.6667  138.9500     53.17
# 552  Quatre Cocos      MU  2021-11-26 22:51:28 -20.2078   57.7625     73.51
# 553          Umba      RU  2021-11-26 22:51:29  66.6871   34.3429     13.91
#
#      Humidity  Cloudiness  Wind Speed
# 0          92          90        3.44
# 1          99          34        5.77
# 2          92         100        7.02
# 3          59         100        5.50
# 4          46          75       21.85
# ..        ...         ...         ...
# 549        93         100        5.97
# 550        89          83        3.44
# 551        53           0       18.32
# 552        70           0        4.81
# 553        91          23        8.95
#
# [554 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
